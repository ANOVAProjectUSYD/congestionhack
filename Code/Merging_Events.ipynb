# %%
import pandas as pd

# %%
merge_data = pd.read_csv('../Datasets/Facebook-Events/merged.csv')

# %%
merge_data
# Out:
#                                              event_name  attendance_count  \
# 0     Toyota AFL Premiership Season R1: West Coast v...               187
# 1     Toyota AFL Premiership Season R1: Melbourne v ...                 5
# 2     Toyota AFL Premiership Season R1: GWS Giants v...                63
# 3     Toyota AFL Premiership Season R1: Gold Coast v...               119
# 4     Toyota AFL Premiership Season R1: Hawthorn v C...               992
# 5     Toyota AFL Premiership Season R1: Port Adelaid...              1554
# 6     Toyota AFL Premiership Season R1: St Kilda v B...               535
# 7                      2018 NAB AFL Women’s GRAND FINAL              1880
# 8     Toyota AFL Premiership Season R1: Essendon v A...              1478
# 9     Toyota AFL Premiership Season R1: Richmond v C...              3975
# 10    2018 NAB AFL Women's Rd 7: Collingwood vs. Ade...               351
# 11    2018 NAB AFL Women's Rd 7: Western Bulldogs vs...               565
# ...
